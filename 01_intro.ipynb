# %% [markdown]
# <a href="https://colab.research.google.com/github/Hussainyar/Python_Cpurse/blob/main/01_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
#
# <div style="background: linear-gradient(90deg, #38bdf8, #0284c7); height: 8px;"></div>
#
# <div style="padding: 80px 40px; text-align: center;">
#
# <div style="color: #38bdf8; font-size: 2.8em; font-weight: bold; margin-bottom: 20px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
# Python for Data Science & AI
# </div>
#
# <div style="color: #64748b; font-size: 1.2em; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
# By Sharif Hussainyar
# </div>
#
# </div>
#
# <div style="background: #f8fafc; padding: 20px 40px; text-align: center; color: #94a3b8; font-size: 0.95em; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
# Lesson 1 • Python for Data Science & AI
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
#
# <div style="background: linear-gradient(90deg, #38bdf8, #0284c7); color: white; padding: 30px 40px; text-align: center;">
#   <h2 style="margin: 0; font-size: 2em;">What Will We Learn?</h2>
# </div>
#
# <div style="padding: 40px; background: #f8fafc;">
#   <h3 style="color: #38bdf8; font-size: 1.3em; margin-bottom: 20px;">📚 Main Topics:</h3>
#
#   <ul style="font-size: 1.1em; line-height: 1.8; color: #0f172a; margin-left: 20px;">
#     <li><strong>Python Fundamentals</strong> — Variables, data types, conditions, loops, functions</li>
#     <li><strong>Working with Data</strong> — Lists, dictionaries, files, basic data processing</li>
#     <li><strong>NumPy & Pandas</strong> — Arrays, tables, cleaning and transforming data</li>
#     <li><strong>Data Visualization</strong> — Matplotlib & Seaborn for charts and graphs</li>
#     <li><strong>Introduction to Machine Learning</strong> — Basic models with scikit-learn</li>
#     <li><strong>Practical Mini‑Projects</strong> — Applying everything to real datasets</li>
#   </ul>
# </div>
#
# <div style="background: #e0f2fe; padding: 20px 40px; border-left: 4px solid #38bdf8;">
#   <p style="color: #0f172a; font-size: 0.95em; margin: 0;">
#     <strong>🎯 Goal:</strong> Build a solid foundation in Python, data science, and basic AI with hands‑on practice.
#   </p>
# </div>
#
# <div style="background: #f8fafc; padding: 20px 40px; text-align: right; color: #94a3b8; font-size: 0.95em;">
# Course Overview • Python for Data Science & AI
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
#
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# What is a Programming Language?
# </div>
#
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Definition**
# - Formal language to instruct computers
# - Translates human logic to machine code
# - Uses syntax rules computers understand
#
# **Key Features**
# - Human-readable syntax
# - Variables store data
# - Control structures (loops, conditionals)
# - Functions for code reuse
#
# </div>
#
# <div style="background: #f8fafc; padding: 20px 40px; text-align: right; color: #94a3b8; font-size: 0.95em; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
# Slide 2 • Python for Data Science & AI
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
#
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Why Do We Need to Learn Programming?
# </div>
#
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Automate Tasks**
# - Save time on repetitive work
# - Process large amounts of data efficiently
# - Reduce human errors
#
# **Build Solutions**
# - Create tools and applications
# - Solve real-world problems
# - Build intelligent systems
#
# **Career & Opportunities**
# - High demand in industry
# - Well-paying jobs globally
# - Growing field with many opportunities
#
# </div>
#
# <div style="background: #f8fafc; padding: 20px 40px; text-align: right; color: #94a3b8; font-size: 0.95em; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
# Slide 3 • Python for Data Science & AI
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
#
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Why Python?
# </div>
#
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Easy to Learn**
# - Simple, readable syntax
# - Similar to human language
# - Beginner-friendly
#
# **Perfect for Data Science**
# - Rich libraries (NumPy, Pandas, Scikit-learn)
# - Easy data visualization (Matplotlib, Seaborn)
# - Machine learning frameworks (TensorFlow, PyTorch)
#
# **Industry Standard**
# - Used by Google, Netflix, Facebook, Amazon
# - Most data scientists use Python
# - Great career opportunities
#
# </div>
#
# <div style="background: #f8fafc; padding: 20px 40px; text-align: right; color: #94a3b8; font-size: 0.95em; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
# Slide 4 • Python for Data Science & AI
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
#
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Python: History & Evolution
# </div>
#
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Timeline**
# - **1989**: Created by Guido van Rossum
# - **1991**: Python 0.9.0 released
# - **2008**: Python 3.0 launched
# - **2020**: Python 2 support ended
#
# **Why "Python"?**
# - Named after "Monty Python" comedy group
# - Designed for clarity and simplicity
# - Fun and approachable language
#
# **Current Status**
# - Python 3.12+ (latest versions)
# - Most popular language for AI/ML
# - Growing rapidly in industry
#
# </div>
#
# <div style="background: #f8fafc; padding: 20px 40px; text-align: right; color: #94a3b8; font-size: 0.95em; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
# Slide 5 • Python for Data Science & AI
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
#
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Getting Started - Setup & Installation
# </div>
#
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **What You'll Need**
# - Python 3.8 or higher
# - A code editor or IDE
# - Internet connection
#
# **Options for This Course**
# - **Google Colab** (Recommended for beginners)
# - **Jupyter Notebook** (Local or online)
# - **VS Code** with Python extension
#
# **Why Google Colab?**
# - No installation needed
# - Free and easy to use
# - Perfect for learning and collaboration
# - Pre-installed libraries
#
# </div>
#
# <div style="background: #f8fafc; padding: 20px 40px; text-align: right; color: #94a3b8; font-size: 0.95em; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
# Slide 6 • Python for Data Science & AI
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
#
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Variables in Python
# </div>
#
# <div style="padding: 40px; background: white; color: #333; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; line-height: 1.8;">
#
# <strong style="color: #38bdf8;">What is a Variable?</strong><br>
# • A container that stores information<br>
# • Like a labeled box holding data<br>
# • You can create, read, and change variables<br><br>
#
# <strong style="color: #38bdf8;">Creating Variables</strong><br>
# • Use a name and assign a value with =<br>
# • Example: <code>name = "Ahmed"</code> or <code>age = 25</code><br>
# • Names should be meaningful and simple<br><br>
#
# <strong style="color: #38bdf8;">Variable Naming Rules</strong><br>
# • Start with a letter or underscore (_)<br>
# • Use letters, numbers, and underscores only<br>
# • No spaces or special characters<br>
# • Good names: <code>my_name</code>, <code>student_age</code>, <code>total_score</code>
#
# </div>
#
# <div style="background: #f8fafc; padding: 20px 40px; text-align: right; color: #94a3b8; font-size: 0.95em; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
# Variables • Python for Data Science & AI
# </div>
#
# </div>

# %% [markdown]
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
#
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Variables in Python
# </div>
#
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **What is a Variable?**
# - A container that stores information
# - Like a labeled box holding data
# - You can create, read, and change variables
#
#
# **Creating Variables**
# - Use a name and assign a value with =
# - Example: `name = "Ahmed"` or `age = 25`
# - Names should be meaningful and simple
#
#
# **Variable Naming Rules**
# - Start with a letter or underscore (_)
# - Use letters, numbers, and underscores only
# - No spaces or special characters
# - Good names: `my_name`, `student_age`, `total_score`

# %% [markdown]
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
#
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Data Types in Python
# </div>
#
# <div style="padding: 40px; background: white; color: #333; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; line-height: 1.8;">
#
# <strong style="color: #38bdf8;">What are Data Types?</strong><br>
# • Categories of data that Python understands<br>
# • Different types for different purposes<br>
# • Python recognizes the type automatically<br><br>
#
# <strong style="color: #38bdf8;">Integer (int)</strong> — Whole numbers<br>
# Example: <code>age = 25</code>, <code>count = -5</code>, <code>year = 2025</code><br><br>
#
# <strong style="color: #38bdf8;">Float (float)</strong> — Numbers with decimals<br>
# Example: <code>height = 1.75</code>, <code>price = 9.99</code>, <code>pi = 3.14</code><br><br>
#
# <strong style="color: #38bdf8;">String (str)</strong> — Text and characters<br>
# Example: <code>name = "Ali"</code>, <code>country = "Afghanistan"</code><br><br>
#
# <strong style="color: #38bdf8;">Boolean (bool)</strong> — True or False values<br>
# Example: <code>is_student = True</code>, <code>is_active = False</code><br><br>
#
# <strong style="color: #38bdf8;">How to Check Type:</strong><br>
# Use <code>type()</code> function: <code>type(age)</code> shows <code>&lt;class 'int'&gt;</code>
#
# </div>
#
# <div style="background: #f8fafc; padding: 20px 40px; text-align: right; color: #94a3b8; font-size: 0.95em; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
# Data Types • Python for Data Science & AI
# </div>
#
# </div>

# %% [markdown]
# ***how are you***
